# %% [markdown]
# # 1. Introdução

# %% [raw]
# A análise abaixo foi realizada utilizando dados do RH da IBM disponibilizados no site www.kaggle.com.
#
# A motivação é entender o perfil das pessoas que deixam a empresa. Isso pode ser importante para prevenir demissões, diminuir custos operacionais e melhorar a satisfação dos empregados, o que, consequentemente, deve aumentar a produtuvidade da empresa.
#
# Perguntas que tentaremos responder com a análise:
#
# -Existe uma disparidade salarial entre hoemns e mulheres?
#
# -Há alguma evidência de que gênero tenha impacto no atrito entre funcionário e empresa?
#
# -Qual a relação entre salário e departamento em que o funcionário atua?
#
#
#  Fonte do dataset:

# %% [markdown]
# <b><i>Forma de pensar na análise: -> Análisar o dataset (estrutura) - Análise Univariada -> Análise Bivariada ou Multivariada - Machine Learning </i><b>

# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd 
import numpy as nd 

import seaborn as sns
import matplotlib.pyplot as plt 

plt.style.use('ggplot') #lyout diferenciado para os graficos

# %% [markdown]
# # Carregando Dataset

# %%
rh = pd.read_csv("C:\\Users\\Lize\\Downloads\\archive (1)\\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
rh.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
rh.info() #estrutura e tipod de dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Análise Univariada - Análisando DataSet

# %%
_ = plt.hist(rh.Age)
_ = plt.title('Grafico de Idade')

# %%
_ = plt.hist(rh.MonthlyIncome )
_ = plt.title('Grafico de Salário')

# %%
rh.Gender.value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
rh.Gender.value_counts(1)
# Out:
# Gender
# Male      0.6
# Female    0.4
# Name: proportion, dtype: float64

# %%
_ = rh.EducationField.value_counts(1).plot.bar()
_ = plt.title('Contagem de Funcionario por Campo Educacional')

# %% [markdown]
# Vemos que a maioria dos funcionarios é formado na area de Life Sciences. Em seguida temos muitos funcionarios da area Medical. A area com menos funcionarios formados e a de Human Resources.

# %% [markdown]
# # Análise Bivariada

# %%
_ = sns.boxplot(x='Gender', y='MonthlyIncome', data=rh)

# %% [markdown]
# Curiosamente, a distribuição entre os genereos é bem parecida. Normalmente, esperace encomntrar uma distruição de salarios mais alktos para hoemns, porem no caso da IBM o gender gap parece não ocorrer

# %%
_ = sns.scatterplot(x='YearsAtCompany', y='MonthlyIncome', data=rh)
